# %% [markdown]
# # Notebook 02: Preprocessing

# %%
import json, time, re, requests, nltk, pickle
import pandas as pd
import psycopg2 as pg2

from psycopg2.extras import RealDictCursor, Json
from requests.packages.urllib3.util.retry import Retry
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer

# %%
# %run ../assets/sql_cred.py
# %run ../assets/spotify_cred.py

# %%
def con_cur_to_db(dbname=DBNAME, dict_cur=None):
    con = pg2.connect(host=IP_ADDRESS,
                  dbname=dbname,
                  user=USER,
                  password=PASSWORD)
    if dict_cur:
        cur = con.cursor(cursor_factory=RealDictCursor)
    else:
        cur = con.cursor()
    return con, cur
    
def execute_query(query, dbname=DBNAME, dict_cur=None, command=False):
    con, cur = con_cur_to_db(dbname, dict_cur)
    cur.execute(f'{query}')
    if not command:
        data = cur.fetchall()
        con.close()
        return data
    con.commit() #sends to server
    con.close() #closes server connection

# %%
query = '''SELECT * FROM track_list;'''
response = execute_query(query, dict_cur=True)
track_df = pd.DataFrame(response)
track_df.set_index('track_id', inplace=True)
track_df.head()
# Out:
#                                                 album_name       artist_name  \
# track_id
# 0h7TlF8gKb61aSm874s3cV  I Can't Tell You How Much It Hurts              moow
# 6koowTu9pFHPEcZnACLKbK                         Coming Home      Leon Bridges
# 1JkhKUXAoNivi87ipmV3rp       Back To Love (Deluxe Version)  Anthony Hamilton
# 51lPx6ZCSalL2kvSrDUyJc           The Search for Everything        John Mayer
# 3vqlZUIT3rEmLaYKDBfb4Q            Songs In The Key Of Life     Stevie Wonder
#
#                                                                    lyrics  \
# track_id
# 0h7TlF8gKb61aSm874s3cV  \n\nIf your needle is near\nNeedle is near\nYo...
# 6koowTu9pFHPEcZnACLKbK  \n\n[Verse 1]\nBrown skin girl on the other si...
# 1JkhKUXAoNivi87ipmV3rp  \n\n[Verse 1]\nIt's simple, I love it\nHaving ...
# 51lPx6ZCSalL2kvSrDUyJc  \n\n[Intro: Whistling]\n\n[Verse 1]\nA great b...
# 3vqlZUIT3rEmLaYKDBfb4Q  \n\n[Verse 1]\nIsn't she lovely\nIsn't she won...
#
#                                    playlist_id  playlist_name playlist_owner  \
# track_id
# 0h7TlF8gKb61aSm874s3cV  37i9dQZF1DXarebqD2nAVg         Tender        spotify
# 6koowTu9pFHPEcZnACLKbK  37i9dQZF1DX4adj7PFEBwf  Wedding Bells        spotify
# 1JkhKUXAoNivi87ipmV3rp  37i9dQZF1DX4adj7PFEBwf  Wedding Bells        spotify
# 51lPx6ZCSalL2kvSrDUyJc  37i9dQZF1DX4adj7PFEBwf  Wedding Bells        spotify
# 3vqlZUIT3rEmLaYKDBfb4Q  37i9dQZF1DX4adj7PFEBwf  Wedding Bells        spotify
#
#                                              track_name
# track_id
# 0h7TlF8gKb61aSm874s3cV                 You'r in My Head
# 6koowTu9pFHPEcZnACLKbK                  Brown Skin Girl
# 1JkhKUXAoNivi87ipmV3rp                       Best of Me
# 51lPx6ZCSalL2kvSrDUyJc  You're Gonna Live Forever in Me
# 3vqlZUIT3rEmLaYKDBfb4Q                 Isn't She Lovely

# %%
track_df = track_df[['track_name','artist_name', 'album_name', 'playlist_name', 'playlist_id', 'lyrics']]
track_df.head()
# Out:
#                                              track_name       artist_name  \
# track_id
# 0h7TlF8gKb61aSm874s3cV                 You'r in My Head              moow
# 6koowTu9pFHPEcZnACLKbK                  Brown Skin Girl      Leon Bridges
# 1JkhKUXAoNivi87ipmV3rp                       Best of Me  Anthony Hamilton
# 51lPx6ZCSalL2kvSrDUyJc  You're Gonna Live Forever in Me        John Mayer
# 3vqlZUIT3rEmLaYKDBfb4Q                 Isn't She Lovely     Stevie Wonder
#
#                                                 album_name  playlist_name  \
# track_id
# 0h7TlF8gKb61aSm874s3cV  I Can't Tell You How Much It Hurts         Tender
# 6koowTu9pFHPEcZnACLKbK                         Coming Home  Wedding Bells
# 1JkhKUXAoNivi87ipmV3rp       Back To Love (Deluxe Version)  Wedding Bells
# 51lPx6ZCSalL2kvSrDUyJc           The Search for Everything  Wedding Bells
# 3vqlZUIT3rEmLaYKDBfb4Q            Songs In The Key Of Life  Wedding Bells
#
#                                    playlist_id  \
# track_id
# 0h7TlF8gKb61aSm874s3cV  37i9dQZF1DXarebqD2nAVg
# 6koowTu9pFHPEcZnACLKbK  37i9dQZF1DX4adj7PFEBwf
# 1JkhKUXAoNivi87ipmV3rp  37i9dQZF1DX4adj7PFEBwf
# 51lPx6ZCSalL2kvSrDUyJc  37i9dQZF1DX4adj7PFEBwf
# 3vqlZUIT3rEmLaYKDBfb4Q  37i9dQZF1DX4adj7PFEBwf
#
#                                                                    lyrics
# track_id
# 0h7TlF8gKb61aSm874s3cV  \n\nIf your needle is near\nNeedle is near\nYo...
# 6koowTu9pFHPEcZnACLKbK  \n\n[Verse 1]\nBrown skin girl on the other si...
# 1JkhKUXAoNivi87ipmV3rp  \n\n[Verse 1]\nIt's simple, I love it\nHaving ...
# 51lPx6ZCSalL2kvSrDUyJc  \n\n[Intro: Whistling]\n\n[Verse 1]\nA great b...
# 3vqlZUIT3rEmLaYKDBfb4Q  \n\n[Verse 1]\nIsn't she lovely\nIsn't she won...

# %%
track_df.dropna(axis=0, inplace=True)

# %%
track_df.shape
# Out:
# (2276, 6)

# %%
lyrics_df = track_df[['track_name','artist_name','lyrics']]

# %%
lyrics_df.head()
# Out:
#                                              track_name       artist_name  \
# track_id
# 0h7TlF8gKb61aSm874s3cV                 You'r in My Head              moow
# 6koowTu9pFHPEcZnACLKbK                  Brown Skin Girl      Leon Bridges
# 1JkhKUXAoNivi87ipmV3rp                       Best of Me  Anthony Hamilton
# 51lPx6ZCSalL2kvSrDUyJc  You're Gonna Live Forever in Me        John Mayer
# 3vqlZUIT3rEmLaYKDBfb4Q                 Isn't She Lovely     Stevie Wonder
#
#                                                                    lyrics
# track_id
# 0h7TlF8gKb61aSm874s3cV  \n\nIf your needle is near\nNeedle is near\nYo...
# 6koowTu9pFHPEcZnACLKbK  \n\n[Verse 1]\nBrown skin girl on the other si...
# 1JkhKUXAoNivi87ipmV3rp  \n\n[Verse 1]\nIt's simple, I love it\nHaving ...
# 51lPx6ZCSalL2kvSrDUyJc  \n\n[Intro: Whistling]\n\n[Verse 1]\nA great b...
# 3vqlZUIT3rEmLaYKDBfb4Q  \n\n[Verse 1]\nIsn't she lovely\nIsn't she won...

# %%
lyrics_df.iloc[1].lyrics
# Out:
# "\n\n[Verse 1]\nBrown skin girl on the other side of the room\nBrown skin girl staring with her brown eyes\nOoh, baby, don't you know you're a cutie pie?\n\n[Chorus]\nPrincess, little honey with the polka-dot dress on\nRuby-lipped lady whose name I don't know\nLet me tell you, darling\nOoh ooh ooh\nOoh whoo-ooh\nOoh ooh ooh\nOoh whoo-ooh, OK\n\n[Verse 2]\nBrown skin girl with the white pearls 'round her neck\nBrown skin girl, let me hold you close under the white moon\nCause baby, I'm ready and you know that I'm waiting on you\n\n[Chorus]\nPrincess, little honey with the polka-dot dress on\nRuby-lipped lady whose name I don't know\nLet me tell you, darling\nOoh ooh ooh\nOoh whoo-ooh\nOoh ooh ooh\nOoh whoo-ooh\nOoh ooh ooh\nOoh whoo-ooh\nOoh ooh ooh\nOoh whoo-ooh\n\n"
